# %%
import pandas as pd
from datetime import datetime, time

# %%
dt1 = pd.Timestamp('2012-01-15')
print("(a) Date time object for Jan 15 2012:", dt1)
# Out:
# (a) Date time object for Jan 15 2012: 2012-01-15 00:00:00

# %%
dt2 = pd.Timestamp('2012-01-15 21:20:00')
print("(b) Specific date and time of 9:20 PM:", dt2)
# Out:
# (b) Specific date and time of 9:20 PM: 2012-01-15 21:20:00

# %%
dt3 = pd.Timestamp.now()
print("(c) Local date and time:", dt3)
# Out:
# (c) Local date and time: 2025-04-24 17:35:22.437943

# %%
dt4 = dt3.date()
print("(d) A date without time:", dt4)
# Out:
# (d) A date without time: 2025-04-24

# %%
dt5 = pd.to_datetime("today").date()
print("(e) Current date:", dt5)
# Out:
# (e) Current date: 2025-04-24

# %%
dt6_time = dt3.time()
print("(f) Time from a datetime:", dt6_time)
# Out:
# (f) Time from a datetime: 17:35:22.437943

# %%
dt7 = datetime.now().time()
print("(g) Current local time:", dt7)
# Out:
# (g) Current local time: 17:35:22.481428
